# %% [markdown]
# <a href="https://colab.research.google.com/github/Govindkaranam/Number-recognition-fromimageofaVechile/blob/main/Char_Recog.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 562.1/562.1 kB 34.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.7/201.7 kB 26.9 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Projects/NLP/Deep_Learning_Project/Characters
# Out:
# /content/drive/MyDrive/Projects/NLP/Deep_Learning_Project/Characters

# %%
# %cd /content/drive/MyDrive/Projects/NLP/Deep_Learning_Project/Characters
# !yolo task = detect mode = train epochs = 75 data = /content/drive/MyDrive/Projects/NLP/Deep_Learning_Project/Characters/No_Plate.yaml  model = /content/drive/MyDrive/Projects/NLP/Deep_Learning_Project/Characters/yolov8m.pt imgsz = 640 batch = 16
# Out:
# /content/drive/MyDrive/Projects/NLP/Deep_Learning_Project/Characters
# Ultralytics YOLOv8.0.92 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task = detect mode = val data = /content/drive/MyDrive/Projects/NLP/Deep_Learning_Project/Characters/No_Plate.yaml model = /content/drive/MyDrive/Projects/NLP/Deep_Learning_Project/Characters/runs/detect/train/weights/best.pt
# Out:
# Ultralytics YOLOv8.0.92 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25860604 parameters, 0 gradients, 78.8 GFLOPs
# val: Scanning /content/drive/MyDrive/Projects/NLP/Deep_Learning_Project/Characters/val/labels.cache... 70 images, 0 backgrounds, 0 corrupt: 100% 70/70 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 5/5 [00:08<00:00,  1.66s/it]
#                    all         70        697      0.938      0.884      0.939      0.709
#                      0         70         90          1      0.953       0.99      0.744
#                      1         70         44      0.987      0.977      0.979      0.625
#                      2         70         31      0.967      0.944      0.988      0.727
#                      3         70         30      0.996          1      0.995      0.777
# ...

# %%
from IPython.display import Image, display

# %%
Image(filename = '/content/drive/MyDrive/Projects/NLP/Deep_Learning_Project/Characters/runs/detect/train/confusion_matrix.png', width = 800)

# %%
Image(filename = '/content/drive/MyDrive/Projects/NLP/Deep_Learning_Project/Characters/runs/detect/train/results.png', width = 800)

# %%
# !yolo detect predict model= /content/drive/MyDrive/Projects/NLP/Deep_Learning_Project/Characters/runs/detect/train/weights/best.pt source = /content/drive/MyDrive/Projects/NLP/Deep_Learning_Project/img save = True
# Out:
# Ultralytics YOLOv8.0.92 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25860604 parameters, 0 gradients, 78.8 GFLOPs
#
# image 1/5 /content/drive/MyDrive/Projects/NLP/Deep_Learning_Project/img/download (1).jpeg: 352x640 1 0, 3 1s, 1 3, 1 6, 1 9, 1 A, 1 D, 1 E, 1 K, 63.0ms
# image 2/5 /content/drive/MyDrive/Projects/NLP/Deep_Learning_Project/img/download.jpeg: 480x640 6 0s, 2 1s, 2 2s, 2 5s, 4 Bs, 2 Ps, 2 Ys, 63.3ms
# image 3/5 /content/drive/MyDrive/Projects/NLP/Deep_Learning_Project/img/download.png: 448x640 2 0s, 6 1s, 5 2s, 7 3s, 3 4s, 2 5s, 2 6s, 9 8s, 2 9s, 6 As, 3 Cs, 1 K, 1 S, 67.9ms
# image 4/5 /content/drive/MyDrive/Projects/NLP/Deep_Learning_Project/img/images (1).jpeg: 384x640 2 0s, 2 1s, 1 7, 1 8, 1 A, 1 E, 1 H, 1 M, 72.6ms
# image 5/5 /content/drive/MyDrive/Projects/NLP/Deep_Learning_Project/img/images.jpeg: 384x640 1 1, 2 2s, 1 3, 1 4, 1 5, 2 As, 1 B, 1 H, 25.9ms
# ...

# %%
import glob
for image_path in glob.glob(f'/content/drive/MyDrive/Projects/NLP/Deep_Learning_Project/Characters/runs/detect/predict/*.jpeg')[:5]:
  display(Image(filename = image_path, height = 600))
  print('\n')
